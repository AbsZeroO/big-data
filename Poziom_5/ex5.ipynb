# %% [markdown]
# # Część 2

# %% [markdown]
# ## 2.1

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType
from pyspark.sql.functions import col, expr, concat, lit, sum, to_date, min, max, avg, count, month, year

spark=SparkSession.builder.appName("BigDataEx5").getOrCreate()

main_df = spark.read.csv("final_data.csv", header=True, inferSchema=True)
main_df = main_df.withColumn("date", to_date(col("date"), "dd/MM/yyyy"))
main_df.show(5)
main_df.printSchema()
# Out:
# +------------+-------------+----------------+------------------+------------+----------+---------------------+------------------+----------------------+----------------------------+----------------------+------------+--------------+-----------------+--------------------+--------------------------+----+--------+---------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+----------+-----------------+-----------+---------------------------+---------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-----------------+------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+------------------+-------------------+-------------------+-------------------+------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-----------------+------------------+-----------------+-----------------+------------------+------------------+----------------+------------------+------------------+-----------------+-----------------+------------------+------------------+----------------+-----------------+-----------------+-----------------+------------------+-----------------+-----------------+-----------------+----------------+-----------------+-----------------+-----------------+------------------+-----------------+------------------+-----------------+------------------+------------------+-----------------+-----------------+------------------+------------------+-------------------+-----------------+------------------+------------------+-----------------+--------------+------------------+-----------------+-----------------+-----------------+------------------+--------------------+------------------+--------------+--------------+------------------+------------------+--------------+--------------+----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# |Country_name|3_letter_code|population_urban|gdp_per_capita_usd|    GDP_2022|      date|Total_confirmed_cases|Total_new_deceased|Total_new_vaccinations|New_persons_fully_vaccinated|Investment_in_vaccines|Total_tested|school_closing|workplace_closing|cancel_public_events|restrictions_on_gatherings|Rank| Capital|Continent|2022 Population|2020 Population|2015 Population|2010 Population|2000 Population|1990 Population|1980 Population|1970 Population|Area (km²)|Density (per km²)|Growth Rate|World Population Percentage|2021 Population|          GDP_1960|          GDP_1961|          GDP_1962|          GDP_1963|          GDP_1964|          GDP_1965|          GDP_1966|         GDP_1967|          GDP_1968|           GDP_1969|           GDP_1970|           GDP_1971|           GDP_1972|           GDP_1973|           GDP_1974|         GDP_1975|          GDP_1976|           GDP_1977|           GDP_1978|           GDP_1979|           GDP_1980|           GDP_1981|           GDP_1982|           GDP_1983|           GDP_1984|           GDP_1985|           GDP_1986|           GDP_1987|           GDP_1988|          GDP_1989|           GDP_1990|           GDP_1991|           GDP_1992|          GDP_1993|           GDP_1994|           GDP_1995|           GDP_1996|           GDP_1997|           GDP_1998|           GDP_1999|           GDP_2000|           GDP_2001|           GDP_2002|           GDP_2003|           GDP_2004|           GDP_2005|           GDP_2006|           GDP_2007|           GDP_2008|           GDP_2009|           GDP_2010|           GDP_2011|           GDP_2012|           GDP_2013|           GDP_2014|           GDP_2015|         GDP_2016|    Inflation_1970|   Inflation_1971|   Inflation_1972|    Inflation_1973|    Inflation_1974|  Inflation_1975|    Inflation_1976|    Inflation_1977|   Inflation_1978|   Inflation_1979|    Inflation_1980|    Inflation_1981|  Inflation_1982|   Inflation_1983|   Inflation_1984|   Inflation_1985|    Inflation_1986|   Inflation_1987|   Inflation_1988|   Inflation_1989|  Inflation_1990|   Inflation_1991|   Inflation_1992|   Inflation_1993|    Inflation_1994|   Inflation_1995|    Inflation_1996|   Inflation_1997|    Inflation_1998|    Inflation_1999|   Inflation_2000|   Inflation_2001|    Inflation_2002|    Inflation_2003|     Inflation_2004|   Inflation_2005|    Inflation_2006|    Inflation_2007|   Inflation_2008|Inflation_2009|    Inflation_2010|   Inflation_2011|   Inflation_2012|   Inflation_2013|    Inflation_2014|      Inflation_2015|    Inflation_2016|Inflation_
384615E11|2.83742493042332E11|2.51499027507641E11|2.47799815768477E11|2.73674236772815E11|2.56706466091089E11|2.69980111642898E11|2.72609288689575E11|2.32439324529645E11|2.385029003119E11|2.7329800128936768|6.475757122039795|6.662487983703613|10.754480361938477|16.936391830444336|17.8114013671875|14.342694282531738|11.793344497680664|7.799351215362549|7.466959476470947|11.594616889953613|11.305756568908691|9.58492660522461|8.366290092468262|7.067662715911865|5.195621967315674|2.9335806369781494|4.113028049468994|5.085931301116943|6.592907428741455|6.14956521987915|4.310207366943359|2.919325351715088|2.190653085708618|1.0885636806488037|0.791237473487854|0.6291998028755188|1.192550778388977|1.3994710445404053|1.1622414588928223|3.042093515396118|2.578436851501465|1.5712209939956665|0.8774445652961731|0.18711966276168823|0.623876690864563|1.5666608810424805|2.5106704235076904|4.065945148468018|           0.0|1.1841391324996948|3.416808843612671|2.808328866958618|1.478294014930725|1.0411959886550903|-0.20792829990386963|0.3566843867301941|         0.839|          1.08|1.1369999647140503|0.2905545556537687|      2.194574|      7.123507|6.25064322154763|            6.503|           11.595|           16.201|           16.426|           17.005|           15.572|           14.967|           13.214|           11.693|           11.134|            10.29|           10.423|           10.469|           10.358|            9.602|            8.935|            6.854|            6.369|            8.249|            8.394|            7.781|            7.689|            8.193|            8.663|            9.376|            8.818|             8.64|            7.361|            6.695|            7.759|            7.617|            6.719|            7.151| 2.19266564982606| 2.76837187403869| 2.85923539795244| 3.00693764122126| 2.53817086908605| 1.97583382585308| 2.83083413396846| 2.26836426727736| 2.25967222789725| 2.43916781644752| 2.50312867558803| 2.24768979633121|  2.2001496661133| 2.04151097052318| 1.64392918654967|  1.6363688680639| 1.61129680187797| 1.49649755696774| 1.34662512995387| 1.21638168386984|  1.5592531612498| 1.46698296751276| 1.64572794344772|             NULL|
# +------------+-------------+----------------+------------------+------------+----------+---------------------+------------------+----------------------+----------------------------+----------------------+------------+--------------+-----------------+--------------------+--------------------------+----+--------+---------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+----------+-----------------+-----------+---------------------------+---------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-----------------+------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+------------------+-------------------+-------------------+-------------------+------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-----------------+------------------+-----------------+-----------------+------------------+------------------+----------------+------------------+------------------+-----------------+-----------------+------------------+------------------+----------------+-----------------+-----------------+-----------------+------------------+-----------------+-----------------+-----------------+----------------+-----------------+-----------------+-----------------+------------------+-----------------+------------------+-----------------+------------------+------------------+-----------------+-----------------+------------------+------------------+-------------------+-----------------+------------------+------------------+-----------------+--------------+------------------+-----------------+-----------------+-----------------+------------------+--------------------+------------------+--------------+--------------+------------------+------------------+--------------+--------------+----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# only showing top 5 rows
# root
#  |-- Country_name: string (nullable = true)
#  |-- 3_letter_code: string (nullable = true)
#  |-- population_urban: integer (nullable = true)
#  |-- gdp_per_capita_usd: integer (nullable = true)
#  |-- GDP_2022: long (nullable = true)
#  |-- date: date (nullable = true)
#  |-- Total_confirmed_cases: integer (nullable = true)
#  |-- Total_new_deceased: integer (nullable = true)
#  |-- Total_new_vaccinations: integer (nullable = true)
#  |-- New_persons_fully_vaccinated: integer (nullable = true)
#  |-- Investment_in_vaccines: long (nullable = true)
#  |-- Total_tested: integer (nullable = true)
#  |-- school_closing: integer (nullable = true)
#  |-- workplace_closing: integer (nullable = true)
#  |-- cancel_public_events: integer (nullable = true)
#  |-- restrictions_on_gatherings: integer (nullable = true)
#  |-- Rank: integer (nullable = true)
#  |-- Capital: string (nullable = true)
#  |-- Continent: string (nullable = true)
#  |-- 2022 Population: integer (nullable = true)
#  |-- 2020 Population: integer (nullable = true)
#  |-- 2015 Population: integer (nullable = true)
#  |-- 2010 Population: integer (nullable = true)
#  |-- 2000 Population: integer (nullable = true)
#  |-- 1990 Population: integer (nullable = true)
#  |-- 1980 Population: integer (nullable = true)
#  |-- 1970 Population: integer (nullable = true)
#  |-- Area (km²): integer (nullable = true)
#  |-- Density (per km²): double (nullable = true)
#  |-- Growth Rate: double (nullable = true)
#  |-- World Population Percentage: double (nullable = true)
#  |-- 2021 Population: double (nullable = true)
#  |-- GDP_1960: double (nullable = true)
#  |-- GDP_1961: double (nullable = true)
#  |-- GDP_1962: double (nullable = true)
#  |-- GDP_1963: double (nullable = true)
#  |-- GDP_1964: double (nullable = true)
#  |-- GDP_1965: double (nullable = true)
#  |-- GDP_1966: double (nullable = true)
#  |-- GDP_1967: double (nullable = true)
#  |-- GDP_1968: double (nullable = true)
#  |-- GDP_1969: double (nullable = true)
#  |-- GDP_1970: double (nullable = true)
#  |-- GDP_1971: double (nullable = true)
#  |-- GDP_1972: double (nullable = true)
#  |-- GDP_1973: double (nullable = true)
#  |-- GDP_1974: double (nullable = true)
#  |-- GDP_1975: double (nullable = true)
#  |-- GDP_1976: double (nullable = true)
#  |-- GDP_1977: double (nullable = true)
#  |-- GDP_1978: double (nullable = true)
#  |-- GDP_1979: double (nullable = true)
#  |-- GDP_1980: double (nullable = true)
#  |-- GDP_1981: double (nullable = true)
#  |-- GDP_1982: double (nullable = true)
#  |-- GDP_1983: double (nullable = true)
#  |-- GDP_1984: double (nullable = true)
#  |-- GDP_1985: double (nullable = true)
#  |-- GDP_1986: double (nullable = true)
#  |-- GDP_1987: double (nullable = true)
#  |-- GDP_1988: double (nullable = true)
#  |-- GDP_1989: double (nullable = true)
#  |-- GDP_1990: double (nullable = true)
#  |-- GDP_1991: double (nullable = true)
#  |-- GDP_1992: double (nullable = true)
#  |-- GDP_1993: double (nullable = true)
#  |-- GDP_1994: double (nullable = true)
#  |-- GDP_1995: double (nullable = true)
#  |-- GDP_1996: double (nullable = true)
#  |-- GDP_1997: double (nullable = true)
#  |-- GDP_1998: double (nullable = true)
#  |-- GDP_1999: double (nullable = true)
#  |-- GDP_2000: double (nullable = true)
#  |-- GDP_2001: double (nullable = true)
#  |-- GDP_2002: double (nullable = true)
#  |-- GDP_2003: double (nullable = true)
#  |-- GDP_2004: double (nullable = true)
#  |-- GDP_2005: double (nullable = true)
#  |-- GDP_2006: double (nullable = true)
#  |-- GDP_2007: double (nullable = true)
#  |-- GDP_2008: double (nullable = true)
#  |-- GDP_2009: double (nullable = true)
#  |-- GDP_2010: double (nullable = true)
#  |-- GDP_2011: double (nullable = true)
#  |-- GDP_2012: double (nullable = true)
#  |-- GDP_2013: double (nullable = true)
#  |-- GDP_2014: double (nullable = true)
#  |-- GDP_2015: double (nullable = true)
#  |-- GDP_2016: double (nullable = true)
#  |-- Inflation_1970: double (nullable = true)
#  |-- Inflation_1971: double (nullable = true)
#  |-- Inflation_1972: double (nullable = true)
#  |-- Inflation_1973: double (nullable = true)
#  |-- Inflation_1974: double (nullable = true)
#  |-- Inflation_1975: double (nullable = true)
#  |-- Inflation_1976: double (nullable = true)
#  |-- Inflation_1977: double (nullable = true)
#  |-- Inflation_1978: double (nullable = true)
#  |-- Inflation_1979: double (nullable = true)
#  |-- Inflation_1980: double (nullable = true)
#  |-- Inflation_1981: double (nullable = true)
#  |-- Inflation_1982: double (nullable = true)
#  |-- Inflation_1983: double (nullable = true)
#  |-- Inflation_1984: double (nullable = true)
#  |-- Inflation_1985: double (nullable = true)
#  |-- Inflation_1986: double (nullable = true)
#  |-- Inflation_1987: double (nullable = true)
#  |-- Inflation_1988: double (nullable = true)
#  |-- Inflation_1989: double (nullable = true)
#  |-- Inflation_1990: double (nullable = true)
#  |-- Inflation_1991: double (nullable = true)
#  |-- Inflation_1992: double (nullable = true)
#  |-- Inflation_1993: double (nullable = true)
#  |-- Inflation_1994: double (nullable = true)
#  |-- Inflation_1995: double (nullable = true)
#  |-- Inflation_1996: double (nullable = true)
#  |-- Inflation_1997: double (nullable = true)
#  |-- Inflation_1998: double (nullable = true)
#  |-- Inflation_1999: double (nullable = true)
#  |-- Inflation_2000: double (nullable = true)
#  |-- Inflation_2001: double (nullable = true)
#  |-- Inflation_2002: double (nullable = true)
#  |-- Inflation_2003: double (nullable = true)
#  |-- Inflation_2004: double (nullable = true)
#  |-- Inflation_2005: double (nullable = true)
#  |-- Inflation_2006: double (nullable = true)
#  |-- Inflation_2007: double (nullable = true)
#  |-- Inflation_2008: double (nullable = true)
#  |-- Inflation_2009: double (nullable = true)
#  |-- Inflation_2010: double (nullable = true)
#  |-- Inflation_2011: double (nullable = true)
#  |-- Inflation_2012: double (nullable = true)
#  |-- Inflation_2013: double (nullable = true)
#  |-- Inflation_2014: double (nullable = true)
#  |-- Inflation_2015: double (nullable = true)
#  |-- Inflation_2016: double (nullable = true)
#  |-- Inflation_2017: double (nullable = true)
#  |-- Inflation_2018: double (nullable = true)
#  |-- Inflation_2019: double (nullable = true)
#  |-- Inflation_2020: double (nullable = true)
#  |-- Inflation_2021: double (nullable = true)
#  |-- Inflation_2022: double (nullable = true)
#  |-- Inflation_2023: double (nullable = true)
#  |-- Unemployment_1991: double (nullable = true)
#  |-- Unemployment_1992: double (nullable = true)
#  |-- Unemployment_1993: double (nullable = true)
#  |-- Unemployment_1994: double (nullable = true)
#  |-- Unemployment_1995: double (nullable = true)
#  |-- Unemployment_1996: double (nullable = true)
#  |-- Unemployment_1997: double (nullable = true)
#  |-- Unemployment_1998: double (nullable = true)
#  |-- Unemployment_1999: double (nullable = true)
#  |-- Unemployment_2000: double (nullable = true)
#  |-- Unemployment_2001: double (nullable = true)
#  |-- Unemployment_2002: double (nullable = true)
#  |-- Unemployment_2003: double (nullable = true)
#  |-- Unemployment_2004: double (nullable = true)
#  |-- Unemployment_2005: double (nullable = true)
#  |-- Unemployment_2006: double (nullable = true)
#  |-- Unemployment_2007: double (nullable = true)
#  |-- Unemployment_2008: double (nullable = true)
#  |-- Unemployment_2009: double (nullable = true)
#  |-- Unemployment_2010: double (nullable = true)
#  |-- Unemployment_2011: double (nullable = true)
#  |-- Unemployment_2012: double (nullable = true)
#  |-- Unemployment_2013: double (nullable = true)
#  |-- Unemployment_2014: double (nullable = true)
#  |-- Unemployment_2015: double (nullable = true)
#  |-- Unemployment_2016: double (nullable = true)
#  |-- Unemployment_2017: double (nullable = true)
#  |-- Unemployment_2018: double (nullable = true)
#  |-- Unemployment_2019: double (nullable = true)
#  |-- Unemployment_2020: double (nullable = true)
#  |-- Unemployment_2021: double (nullable = true)
#  |-- Unemployment_2022: double (nullable = true)
#  |-- Unemployment_2023: double (nullable = true)
#  |-- Murders_Rate_1998: double (nullable = true)
#  |-- Murders_Rate_1999: double (nullable = true)
#  |-- Murders_Rate_2000: double (nullable = true)
#  |-- Murders_Rate_2001: double (nullable = true)
#  |-- Murders_Rate_2002: double (nullable = true)
#  |-- Murders_Rate_2003: double (nullable = true)
#  |-- Murders_Rate_2004: double (nullable = true)
#  |-- Murders_Rate_2005: double (nullable = true)
#  |-- Murders_Rate_2006: double (nullable = true)
#  |-- Murders_Rate_2007: double (nullable = true)
#  |-- Murders_Rate_2008: double (nullable = true)
#  |-- Murders_Rate_2009: double (nullable = true)
#  |-- Murders_Rate_2010: double (nullable = true)
#  |-- Murders_Rate_2011: double (nullable = true)
#  |-- Murders_Rate_2012: double (nullable = true)
#  |-- Murders_Rate_2013: double (nullable = true)
#  |-- Murders_Rate_2014: double (nullable = true)
#  |-- Murders_Rate_2015: double (nullable = true)
#  |-- Murders_Rate_2016: double (nullable = true)
#  |-- Murders_Rate_2017: double (nullable = true)
#  |-- Murders_Rate_2018: double (nullable = true)
#  |-- Murders_Rate_2019: double (nullable = true)
#  |-- Murders_Rate_2020: double (nullable = true)
#  |-- Murders_Rate_2021: double (nullable = true)

# %% [markdown]
# ## 2.2 i 2.3

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

# Ręcznie definiujesz schemat tylko dla wybranych kolumn
schema_manual = StructType([
    StructField("Country_name", StringType(), True),
    StructField("3_letter_code", StringType(), True),
    StructField("population_urban", IntegerType(), True),
    StructField("gdp_per_capita_usd", DoubleType(), True),
    StructField("date", StringType(), True),
    StructField("Total_confirmed_cases", IntegerType(), True),
    StructField("Total_new_deceased", IntegerType(), True),
    StructField("Total_new_vaccinations", IntegerType(), True),
    StructField("Area (km²)", DoubleType(), True),
    StructField("Density (per km²)", DoubleType(), True),
    StructField("2022 Population", IntegerType(), True)
])

wanted_cols = [field.name for field in schema_manual.fields]

df_selected = main_df.select(wanted_cols)

# To nie działa bo spark idzie po kolei od lewej do prawej i bierze pierwsze 
#df_selected = spark.read.csv("final_data.csv", header=True, schema=schema_manual)

df_selected.printSchema()
df_selected.show(5)
# Out:
# root
#  |-- Country_name: string (nullable = true)
#  |-- 3_letter_code: string (nullable = true)
#  |-- population_urban: integer (nullable = true)
#  |-- gdp_per_capita_usd: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- Total_confirmed_cases: integer (nullable = true)
#  |-- Total_new_deceased: integer (nullable = true)
#  |-- Total_new_vaccinations: integer (nullable = true)
#  |-- Area (km²): integer (nullable = true)
#  |-- Density (per km²): double (nullable = true)
#  |-- 2022 Population: integer (nullable = true)
#
# +------------+-------------+----------------+------------------+----------+---------------------+------------------+----------------------+----------+-----------------+---------------+
# |Country_name|3_letter_code|population_urban|gdp_per_capita_usd|      date|Total_confirmed_cases|Total_new_deceased|Total_new_vaccinations|Area (km²)|Density (per km²)|2022 Population|
# +------------+-------------+----------------+------------------+----------+---------------------+------------------+----------------------+----------+-----------------+---------------+
# |     Finland|          FIN|         4716888|             50150|2021-01-17|                  236|                 1|                 62050|    338424|          16.3722|        5540745|
# |     Finland|          FIN|         4716888|             50150|2021-01-24|                  246|                 5|                 53248|    338424|          16.3722|        5540745|
# |     Finland|          FIN|         4716888|             50150|2021-01-31|                  367|                 6|                 41790|    338424|          16.3722|        5540745|
# |     Finland|          FIN|         4716888|             50150|2021-02-07|                  354|                 5|                 22331|    338424|          16.3722|        5540745|
# |     Finland|          FIN|         4716888|             50150|2021-02-14|                  312|                 1|                 39386|    338424|          16.3722|        5540745|
# +------------+-------------+----------------+------------------+----------+---------------------+------------------+----------------------+----------+-----------------+---------------+
# only showing top 5 rows

# %% [markdown]
# ## 2.4

# %%
df = df_selected.withColumn(
    "urban_population_ratio",
    expr("try_divide(population_urban, `2022 Population`)")
)
df.show(5)
# Out:
# +------------+-------------+----------------+------------------+----------+---------------------+------------------+----------------------+----------+-----------------+---------------+----------------------+
# |Country_name|3_letter_code|population_urban|gdp_per_capita_usd|      date|Total_confirmed_cases|Total_new_deceased|Total_new_vaccinations|Area (km²)|Density (per km²)|2022 Population|urban_population_ratio|
# +------------+-------------+----------------+------------------+----------+---------------------+------------------+----------------------+----------+-----------------+---------------+----------------------+
# |     Finland|          FIN|         4716888|             50150|2021-01-17|                  236|                 1|                 62050|    338424|          16.3722|        5540745|    0.8513093455843934|
# |     Finland|          FIN|         4716888|             50150|2021-01-24|                  246|                 5|                 53248|    338424|          16.3722|        5540745|    0.8513093455843934|
# |     Finland|          FIN|         4716888|             50150|2021-01-31|                  367|                 6|                 41790|    338424|          16.3722|        5540745|    0.8513093455843934|
# |     Finland|          FIN|         4716888|             50150|2021-02-07|                  354|                 5|                 22331|    338424|          16.3722|        5540745|    0.8513093455843934|
# |     Finland|          FIN|         4716888|             50150|2021-02-14|                  312|                 1|                 39386|    338424|          16.3722|        5540745|    0.8513093455843934|
# +------------+-------------+----------------+------------------+----------+---------------------+------------------+----------------------+----------+-----------------+---------------+----------------------+
# only showing top 5 rows

# %% [markdown]
# ## 2.5

# %%
df_with_concat = df_selected.withColumn(
    "country_info",
    concat(
        col("Country_name"),
        lit(" ("),
        col("3_letter_code"),
        lit(") - "),
        col("date")
    )
)

df_with_concat.show(5, truncate=False)
# Out:
# +------------+-------------+----------------+------------------+----------+---------------------+------------------+----------------------+----------+-----------------+---------------+--------------------------+
# |Country_name|3_letter_code|population_urban|gdp_per_capita_usd|date      |Total_confirmed_cases|Total_new_deceased|Total_new_vaccinations|Area (km²)|Density (per km²)|2022 Population|country_info              |
# +------------+-------------+----------------+------------------+----------+---------------------+------------------+----------------------+----------+-----------------+---------------+--------------------------+
# |Finland     |FIN          |4716888         |50150             |2021-01-17|236                  |1                 |62050                 |338424    |16.3722          |5540745        |Finland (FIN) - 2021-01-17|
# |Finland     |FIN          |4716888         |50150             |2021-01-24|246                  |5                 |53248                 |338424    |16.3722          |5540745        |Finland (FIN) - 2021-01-24|
# |Finland     |FIN          |4716888         |50150             |2021-01-31|367                  |6                 |41790                 |338424    |16.3722          |5540745        |Finland (FIN) - 2021-01-31|
# |Finland     |FIN          |4716888         |50150             |2021-02-07|354                  |5                 |22331                 |338424    |16.3722          |5540745        |Finland (FIN) - 2021-02-07|
# |Finland     |FIN          |4716888         |50150             |2021-02-14|312                  |1                 |39386                 |338424    |16.3722          |5540745        |Finland (FIN) - 2021-02-14|
# +------------+-------------+----------------+------------------+----------+---------------------+------------------+----------------------+----------+-----------------+---------------+--------------------------+
# only showing top 5 rows

# %% [markdown]
# ## 2.6

# %%
# 1. Kraje z gdp_per_capita_usd większym niż 100000
df1 = main_df.filter(col("gdp_per_capita_usd") > 100000).select("Country_name", "gdp_per_capita_usd").distinct()
df1.show(5)
df1.write.csv("wyniki_2_6/high_gdp_countries", header=True, mode="overwrite")
# Out:
# +-------------+------------------+
# | Country_name|gdp_per_capita_usd|
# +-------------+------------------+
# |   Luxembourg|            116348|
# |Liechtenstein|            173356|
# +-------------+------------------+

# %%
# 2. Kraje z populacją miejską większą niż 50 milionów
df2 = main_df.filter(col("population_urban") > 50000000).select("Country_name", "population_urban").distinct()
df2.show(5)
df2.write.csv("wyniki_2_6/large_urban_population", header=True, mode="overwrite")
# Out:
# +--------------+----------------+
# |  Country_name|population_urban|
# +--------------+----------------+
# |        Mexico|       102626859|
# |United Kingdom|        55908316|
# |    Bangladesh|        60987417|
# |        France|        54123364|
# |   Philippines|        50975903|
# +--------------+----------------+
# only showing top 5 rows

# %%
# 3. Kraje z gęstością zaludnienia większą niż 1000 osób/km²
df3 = main_df.filter(col("Density (per km²)") > 1000).select("Country_name", "Density (per km²)").distinct()
df3.show(5)
df3.write.csv("wyniki_2_6/high_density_countries", header=True, mode="overwrite")
# Out:
# +------------+-----------------+
# |Country_name|Density (per km²)|
# +------------+-----------------+
# |  Bangladesh|         1160.035|
# |     Bahrain|        1924.4876|
# |   Singapore|        8416.4634|
# |     Bermuda|        1188.5926|
# |    Maldives|        1745.9567|
# +------------+-----------------+
# only showing top 5 rows

# %%
# 4. Kraje, gdzie liczba nowych zgonów COVID jest większa niż 1000 w danym dniu
df4 = main_df.filter(col("Total_new_deceased") > 1000).select("Country_name", "date", "Total_new_deceased").distinct()
df4.show(5)
df4.write.csv("wyniki_2_6/high_covid_deaths", header=True, mode="overwrite")
# Out:
# +--------------+----------+------------------+
# |  Country_name|      date|Total_new_deceased|
# +--------------+----------+------------------+
# |        Mexico|2021-01-08|              1197|
# |        Mexico|2021-01-16|              1294|
# |United Kingdom|2021-01-13|              1219|
# |        Mexico|2021-01-17|              1402|
# |        Mexico|2021-01-25|              1478|
# +--------------+----------+------------------+
# only showing top 5 rows

# %%
# 6. Kraje, gdzie łączna liczba nowych szczepień przekracza 100 000 000
df6 = main_df.groupBy("Country_name") \
    .agg(sum("Total_new_vaccinations").alias("total_vaccinations")) \
    .filter(col("total_vaccinations") > 100000000)

df6.show(5)
df6.write.csv("wyniki_2_6/high_total_vaccinations", header=True, mode="overwrite")
# Out:
# +--------------------+------------------+
# |        Country_name|total_vaccinations|
# +--------------------+------------------+
# |          Bangladesh|         127358755|
# |           Indonesia|         188810480|
# |              Brazil|         141361044|
# |               India|         980066849|
# |United States of ...|         259495882|
# +--------------------+------------------+
# only showing top 5 rows

# %%
# 7. Dni, w których w Finlandi było powyżej 20 zgonów
df7 = main_df.filter(col("Total_new_deceased") > 20).filter(col("Country_name") == "Finland").select("Country_name", "date", "Total_new_deceased").orderBy(col("Total_new_deceased").desc())
df7.show(5)
df7.write.csv("wyniki_2_6/date_when_deceased_gt_500_Finland", header=True, mode="overwrite", sep=",")
# Out:
# +------------+----------+------------------+
# |Country_name|      date|Total_new_deceased|
# +------------+----------+------------------+
# |     Finland|2022-03-23|                50|
# |     Finland|2022-03-07|                40|
# |     Finland|2022-03-06|                35|
# |     Finland|2022-04-05|                34|
# |     Finland|2022-03-08|                30|
# +------------+----------+------------------+
# only showing top 5 rows

# %%
# 8. Kiedy i w jakich krajach osoby były w pełni zaszczepione
df8 = main_df.filter(col("New_persons_fully_vaccinated") > 0).groupBy("Country_name").agg(min("date").alias("New_persons_fully_vaccinated")).orderBy("New_persons_fully_vaccinated")
df8.show(5)
df8.write.csv("wyniki_2_6/countries_and_date_fully_vaccinated", header=True, mode="overwrite", sep=",")
# Out:
# +--------------------+----------------------------+
# |        Country_name|New_persons_fully_vaccinated|
# +--------------------+----------------------------+
# |United States of ...|                  2020-12-14|
# |         Switzerland|                  2020-12-21|
# |              France|                  2020-12-27|
# |             Estonia|                  2020-12-28|
# |      Czech Republic|                  2020-12-29|
# +--------------------+----------------------------+
# only showing top 5 rows

# %%
# 9. Pierwsze szczepienia kiedy i gdzie
df9 = main_df.filter(col("Total_new_vaccinations") > 0).select("Country_name", "date", "Total_new_vaccinations").orderBy("date")
df9.show(5)
df9.write.csv("wyniki_2_6/countries_and_date_first_vaccinated", header=True, mode="overwrite", sep=",")
# Out:
# +------------+----------+----------------------+
# |Country_name|      date|Total_new_vaccinations|
# +------------+----------+----------------------+
# |      Latvia|2020-12-07|                     1|
# |      Norway|2020-12-08|                     5|
# |      Latvia|2020-12-09|                     1|
# |      Norway|2020-12-09|                     1|
# |      Norway|2020-12-10|                     1|
# +------------+----------+----------------------+
# only showing top 5 rows

# %%
# 10. Kraje z PKB per capita między 20000 a 50000 USD
df10 = main_df.filter((col("gdp_per_capita_usd") >= 20000) & (col("gdp_per_capita_usd") <= 50000)) \
    .select("Country_name", "gdp_per_capita_usd").distinct()
df10.show(5)
df10.write.csv("wyniki_2_6/gdp_midrange", header=True, mode="overwrite")
# Out:
# +--------------+------------------+
# |  Country_name|gdp_per_capita_usd|
# +--------------+------------------+
# |  Saudi Arabia|             23139|
# |United Kingdom|             43070|
# |        France|             41300|
# |         Aruba|             29007|
# |        Greece|             20296|
# +--------------+------------------+
# only showing top 5 rows

# %% [markdown]
# ## 2.7

# %%
# 1. Liczba dni, w których liczba nowych testów była większa niż 100000
df11 = main_df.filter(col("Total_tested") > 100000).groupBy("Country_name").agg(count("date").alias("days_with_more_than_100000_tests")).orderBy("Country_name")
df11.show(5)
df11.write.csv("wyniki_2_7/days_with_tested_gt_100000", header=True, mode="overwrite", sep=",")
# Out:
# +------------+--------------------------------+
# |Country_name|days_with_more_than_100000_tests|
# +------------+--------------------------------+
# |   Argentina|                              25|
# |   Australia|                             271|
# |     Austria|                             508|
# |     Belgium|                              38|
# |      Brazil|                             259|
# +------------+--------------------------------+
# only showing top 5 rows

# %%
# 2. Suma wszystkich nowych szczepień dla każdego kraju
df12 = main_df.groupBy("Country_name").agg(sum("Total_new_vaccinations").alias("total_new_vaccinations")).orderBy("Country_name")
df12.show(5)
df12.write.csv("wyniki_2_7/total_vaccinations_per_country", header=True, mode="overwrite", sep=",")
# Out:
# +------------+----------------------+
# |Country_name|total_new_vaccinations|
# +------------+----------------------+
# |     Albania|               1216854|
# |   Argentina|              17660829|
# |     Armenia|               1129104|
# |       Aruba|                   332|
# |   Australia|              41514738|
# +------------+----------------------+
# only showing top 5 rows

# %%
# 3. Maksymalna liczba potwierdzonych przypadków w jednym dniu dla każdego kraju
df13 = main_df.groupBy("Country_name").agg(max("Total_confirmed_cases").alias("max_confirmed_cases")).orderBy("Country_name")
df13.show(5)
df13.write.csv("wyniki_2_7/max_confirmed_cases_per_day", header=True, mode="overwrite", sep=",")
# Out:
# +------------+-------------------+
# |Country_name|max_confirmed_cases|
# +------------+-------------------+
# |     Albania|               2177|
# |   Argentina|             174174|
# |     Armenia|               3127|
# |       Aruba|                  3|
# |   Australia|             150702|
# +------------+-------------------+
# only showing top 5 rows

# %%
# 4. Średnia liczba zmarłych dla kraju
df14 = main_df.groupBy("Country_name").agg(avg("Total_new_deceased").alias("avg_new_deceased")).orderBy("Country_name")
df14.show(5)
df14.write.csv("wyniki_2_7/average_new_confirmed", header=True, mode="overwrite", sep=",")
# Out:
# +------------+------------------+
# |Country_name|  avg_new_deceased|
# +------------+------------------+
# |     Albania| 4.675438596491228|
# |   Argentina|158.65774378585087|
# |     Armenia|13.708333333333334|
# |       Aruba|               0.0|
# |   Australia|15.663419913419913|
# +------------+------------------+
# only showing top 5 rows

# %%
# 5. Nowi w pełni zaszczepieni w kazdym dniu
df15 = main_df.groupBy("date").agg(sum("New_persons_fully_vaccinated").alias("global_fully_vaccinated"))
df15.show(5)
df15.write.csv("wyniki_2_7/global_deceased", header=True, mode="overwrite", sep=",")
# Out:
# +----------+-----------------------+
# |      date|global_fully_vaccinated|
# +----------+-----------------------+
# |2021-06-22|                6257511|
# |2021-08-27|               12374078|
# |2021-01-27|                 942969|
# |2021-10-11|                7787152|
# |2021-11-13|                8025234|
# +----------+-----------------------+
# only showing top 5 rows

# %% [markdown]
# ## 2.8

# %%
main_df = main_df.withColumn("date_parsed", to_date(col("date"), "yyyy-MM-dd"))

main_df = main_df.withColumn("month", month(col("date_parsed")))
main_df = main_df.withColumn("year", year(col("date_parsed")))


monthly_covid_cases = main_df.groupBy("year", "month") \
    .agg(sum("Total_confirmed_cases").alias("monthly_confirmed_cases")) \
    .orderBy("year", "month")

monthly_covid_cases.show(10)
monthly_covid_cases.write.csv("wyniki_2_8/monthly_covid_cases", header=True, mode="overwrite", sep=",")
# Out:
# +----+-----+-----------------------+
# |year|month|monthly_confirmed_cases|
# +----+-----+-----------------------+
# |2020|    2|                      2|
# |2020|    3|                  10220|
# |2020|    4|                  81909|
# |2020|    5|                 429295|
# |2020|    6|                 888503|
# |2020|    7|                1269888|
# |2020|    8|                1255338|
# |2020|    9|                 904111|
# |2020|   10|                 725208|
# |2020|   11|                 800592|
# +----+-----+-----------------------+
# only showing top 10 rows

# %% [markdown]
# ## 2.9

# %%
inner_join_df = df3.join(df2, on="Country_name", how="inner")
inner_join_df.show(5)
inner_join_df.write.csv("wyniki_2_9/inner_join", header=True, mode="overwrite", sep=",")
# Tylko kraje spełniające oba warunki: wysokie GDP i duża populacja miejska
# Out:
# +------------+-----------------+----------------+
# |Country_name|Density (per km²)|population_urban|
# +------------+-----------------+----------------+
# |  Bangladesh|         1160.035|        60987417|
# +------------+-----------------+----------------+

# %%
left_join_df = df1.join(df2, on="Country_name", how="left")
left_join_df.show()
left_join_df.write.csv("wyniki_2_9/left_join", header=True, mode="overwrite", sep=",")
# Kraje z wysokim GDP + NULL bo nie mają populacji > 50 mln
# Out:
# +-------------+------------------+----------------+
# | Country_name|gdp_per_capita_usd|population_urban|
# +-------------+------------------+----------------+
# |   Luxembourg|            116348|            NULL|
# |Liechtenstein|            173356|            NULL|
# +-------------+------------------+----------------+

# %%
right_join_df = df1.join(df2, on="Country_name", how="right")
right_join_df.show()
right_join_df.write.csv("wyniki_2_9/right_join", header=True, mode="overwrite", sep=",")
# Kraje z wysokim GDP + NULL bo nie mają populacji > 50 mln
# Out:
# +--------------------+------------------+----------------+
# |        Country_name|gdp_per_capita_usd|population_urban|
# +--------------------+------------------+----------------+
# |              Mexico|              NULL|       102626859|
# |      United Kingdom|              NULL|        55908316|
# |          Bangladesh|              NULL|        60987417|
# |              France|              NULL|        54123364|
# |         Philippines|              NULL|        50975903|
# |           Indonesia|              NULL|       151509724|
# |                Iran|              NULL|        62509623|
# |              Brazil|              NULL|       183241641|
# |              Turkey|              NULL|        63097818|
# |United States of ...|              NULL|       270663028|
# |               India|              NULL|       471031528|
# |               Japan|              NULL|       115782416|
# |            Pakistan|              NULL|        79927762|
# |              Russia|              NULL|       107683889|
# +--------------------+------------------+----------------+

# %%
outer_join_df = df1.join(df2, on="Country_name", how="outer")
outer_join_df.show()
outer_join_df.write.csv("wyniki_2_9/outer_join_df", header=True, mode="overwrite", sep=",")
# Wszystkie kraje: bogate, miejskie i pozostałe – nawet jeśli nie pasują
# Out:
# +--------------------+------------------+----------------+
# |        Country_name|gdp_per_capita_usd|population_urban|
# +--------------------+------------------+----------------+
# |          Bangladesh|              NULL|        60987417|
# |              Brazil|              NULL|       183241641|
# |              France|              NULL|        54123364|
# |               India|              NULL|       471031528|
# |           Indonesia|              NULL|       151509724|
# |                Iran|              NULL|        62509623|
# |               Japan|              NULL|       115782416|
# |       Liechtenstein|            173356|            NULL|
# |          Luxembourg|            116348|            NULL|
# |              Mexico|              NULL|       102626859|
# |            Pakistan|              NULL|        79927762|
# |         Philippines|              NULL|        50975903|
# |              Russia|              NULL|       107683889|
# |              Turkey|              NULL|        63097818|
# |      United Kingdom|              NULL|        55908316|
# |United States of ...|              NULL|       270663028|
# +--------------------+------------------+----------------+

# %%
left_semi_df = df3.join(df6, on="Country_name", how="left_semi")
left_semi_df.show(5)
left_semi_df.write.csv("wyniki_2_9/left_semi", header=True, mode="overwrite", sep=",")
# Pokaż tylko te kraje z dużą gęstością zaludnienia, które mają łącznie ponad 100 milionów szczepień.
# Out:
# +------------+-----------------+
# |Country_name|Density (per km²)|
# +------------+-----------------+
# |  Bangladesh|         1160.035|
# +------------+-----------------+

# %%
left_anti_df = df10.join(df4, on="Country_name", how="left_anti")
left_anti_df.show(5)
left_anti_df.write.csv("wyniki_2_9/left_anti", header=True, mode="overwrite", sep=",")
# Pokaż kraje z PKB między 20k–50k USD, które nie miały pojedynczego dnia z >1000 zgonów.
# Out:
# +--------------------+------------------+
# |        Country_name|gdp_per_capita_usd|
# +--------------------+------------------+
# |        Saudi Arabia|             23139|
# |              France|             41300|
# |               Aruba|             29007|
# |              Greece|             20296|
# |United Arab Emirates|             43103|
# +--------------------+------------------+
# only showing top 5 rows

# %%
cross_join_df = df3.crossJoin(df7)
cross_join_df.show(5)
cross_join_df.write.csv("wyniki_2_9/cross_join", header=True, mode="overwrite", sep=",")
# Stworzy wszystkie możliwe pary między krajami o dużej gęstości i dniami w Finlandii z dużą liczbą zgonów – może służyć do generowania scenariuszy lub testów korelacji.
# Out:
# +------------+-----------------+------------+----------+------------------+
# |Country_name|Density (per km²)|Country_name|      date|Total_new_deceased|
# +------------+-----------------+------------+----------+------------------+
# |  Bangladesh|         1160.035|     Finland|2022-01-03|                23|
# |  Bangladesh|         1160.035|     Finland|2022-01-25|                21|
# |  Bangladesh|         1160.035|     Finland|2022-01-26|                21|
# |  Bangladesh|         1160.035|     Finland|2022-01-30|                26|
# |  Bangladesh|         1160.035|     Finland|2022-02-01|                29|
# +------------+-----------------+------------+----------+------------------+
# only showing top 5 rows
